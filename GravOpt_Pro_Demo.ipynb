# %% [markdown]
# <a href="https://colab.research.google.com/github/Kretski/GravOpt-Pro/blob/main/GravOpt_Pro_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GravOpt Pro Buy – Open only on even dates 13:00–16:00 Sofia time
import datetime
import pytz
from IPython.display import HTML, display

tz = pytz.timezone('Europe/Sofia')
now = datetime.datetime.now(tz)
is_even = (now.day % 2 == 0)
is_open = is_even and 13 <= now.hour < 16

if is_open:
    display(HTML(f"""
    <div style="text-align:center;padding:60px;background:#000;color:#00ff41;font-family:Arial;border:5px solid #00ff41;border-radius:25px;">
    <h1 style="font-size:60px;">GRAVOPT PRO – OPEN NOW</h1>
    <h2>{now.strftime('%d %B %Y · %H:%M')} Sofia (even date)</h2>
    <p style="font-size:32px;margin:30px 0;">First 100 licenses – €200 (regular €590)</p>
    <a href="https://buy.stripe.com/14A28r4rEfYEaUgfwh4c800" target="_blank">
      <button style="font-size:50px;padding:25px 80px;background:#00ff41;color:black;border:none;border-radius:20px;cursor:pointer;">
      BUY NOW – €200
      </button>
    </a>
    <p style="margin-top:40px;font-size:24px;">
      or test AzuroNanoOpt demo 24/7 → <a href="https://bit.ly/AzuroDroneLive" style="color:#00ff41;">bit.ly/AzuroDroneLive</a>
    </p>
    </div>
    """))
else:
    next_day = now.day + 1 if now.day % 2 == 1 else now.day + 2
    display(HTML(f"""
    <div style="text-align:center;padding:70px;background:#000;color:#ff0040;font-family:Arial;border:5px solid #ff0040;border-radius:25px;">
    <h1 style="font-size:58px;">GRAVOPT PRO – CLOSED</h1>
    <p style="font-size:28px;">Current time: <b>{now.strftime('%d %B %Y · %H:%M')}</b> Sofia</p>
    <p style="font-size:30px;">Open only on <b>even dates</b> from 13:00 – 16:00 local time</p>
    <p style="font-size:26px;">Next opening: <b>{next_day:02d} {now.strftime('%B %Y')} · 13:00</b></p>
    <hr style="border:1px solid #555;width:70%;">
    <p style="font-size:28px;color:#00ff41;">Try AzuroNanoOpt live demo (24/7):</p>
    <a href="https://bit.ly/AzuroDroneLive" target="_blank">
      <button style="font-size:42px;padding:20px 70px;background:#333;color:#00ff41;border:3px solid #00ff41;border-radius:15px;">
      LAUNCH DEMO NOW
      </button>
    </a>
    </div>
    """))
# Out:
#     <div style="text-align:center;padding:60px;background:#000;color:#00ff41;font-family:Arial;border:5px solid #00ff41;border-radius:25px;">
#     <h1 style="font-size:60px;">GRAVOPT PRO – OPEN NOW</h1>
#     <h2>26 November 2025 · 13:30 Sofia (even date)</h2>
#     <p style="font-size:32px;margin:30px 0;">First 100 licenses – €200 (regular €590)</p>
#     <a href="https://buy.stripe.com/14A28r4rEfYEaUgfwh4c800" target="_blank">
#       <button style="font-size:50px;padding:25px 80px;background:#00ff41;color:black;border:none;border-radius:20px;cursor:pointer;">
#       BUY NOW – €200
#       </button>
#     </a>
#     <p style="margin-top:40px;font-size:24px;">
#       or test AzuroNanoOpt demo 24/7 → <a href="https://bit.ly/AzuroDroneLive" style="color:#00ff41;">bit.ly/AzuroDroneLive</a>
#     </p>
#     </div>
